# %%
price1 = 100
price2 = 200
tax = 1.1
sum =  (price1*tax) + (price2*tax)

def total(price1,price2):
  price1 = 100
  price2 = 200
  tax = 1.1
  a = (price1*tax) + (price2*tax)
  print(a)

total(100,200)
print (sum)
# Out:
# 330.00000000000006
# 330.00000000000006
